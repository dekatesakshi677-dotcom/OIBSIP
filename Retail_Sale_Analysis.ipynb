# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# df = pd.read_csv('retail_sales_dataset.csv')
print(df.head()) #

# Basic statistics (Mean, Median, Standard Deviation)
print(df.describe())

# Convert 'Date' column to datetime objects
df['Date'] = pd.to_datetime(df['Date'])

# Set 'Date' as the DataFrame index
df.set_index('Date', inplace=True)

# Resample data monthly and sum 'Total Amount' for plotting
df.resample('ME')['Total Amount'].sum().plot()
plt.title('Monthly Sales Trend')
plt.ylabel('Total Sales Amount')
plt.xlabel('Date')
plt.grid(True)
plt.tight_layout()
plt.show()

# Product Category wise sales
sns.countplot(x='Product Category', data=df)
plt.title('Product Category Sales')
plt.ylabel('Number of Sales')
plt.xlabel('Product Category')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# ...

# %% [markdown]
# # Actionable Recommendations Based On The EDA.
#
# Insight 1: Peak Sales Period
# Based on the Time Series Analysis, sales peaked significantly in May 2023. The business should plan major marketing campaigns and seasonal offers around this month to maximize revenue.
#
# Insight 2: Top Performing Category
# The Clothing category has the highest number of sales compared to Beauty and Electronics. The business should focus on expanding the inventory and variety within the clothing section.
#
# Insight 3: Inventory Management
# Since there is a noticeable dip in sales during September, the business should introduce clearance sales or loyalty discounts during this period to maintain steady cash flow.
